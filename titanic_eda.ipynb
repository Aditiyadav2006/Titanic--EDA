# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %%
uploaded = files.upload()
df=pd.read_csv('train.csv')
df.head(10)
# Out:
#      <input type="file" id="files-4acd217d-758f-4334-92a3-dbb4e963295f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4acd217d-758f-4334-92a3-dbb4e963295f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.describe().T
# Out:
#              count        mean         std   min       25%       50%    75%  \
# PassengerId  891.0  446.000000  257.353842  1.00  223.5000  446.0000  668.5
# Survived     891.0    0.383838    0.486592  0.00    0.0000    0.0000    1.0
# Pclass       891.0    2.308642    0.836071  1.00    2.0000    3.0000    3.0
# Age          714.0   29.699118   14.526497  0.42   20.1250   28.0000   38.0
# SibSp        891.0    0.523008    1.102743  0.00    0.0000    0.0000    1.0
# Parch        891.0    0.381594    0.806057  0.00    0.0000    0.0000    0.0
# Fare         891.0   32.204208   49.693429  0.00    7.9104   14.4542   31.0
#
#                   max
# PassengerId  891.0000
# Survived       1.0000
# Pclass         3.0000
# Age           80.0000
# SibSp          8.0000
# Parch          6.0000
# Fare         512.3292

# %%
df.PassengerId
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.PassengerId
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
#plotting age distrubution
#df.Age.plot(kind='hist')
df.Age.hist(bins=10,edgecolor='black')
plt.title('Age Dist')
plt.xlabel('Age')
plt.ylabel('Freq')
plt.show()

df.Survived.hist(bins=30,edgecolor='red')
plt.title('Survival dist')
plt.xlabel('survival dist')
plt.ylabel('Freq')
plt.show()

# %%
df.Survived.value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df.Age.value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 30.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
df.Sex.nunique()
# Out:
# 2

# %%
df.Age.nunique()
# Out:
# 88

# %%
df.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
df.types()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-30-1697157781.py in <cell line: 0>()
# ----> 1 df.types()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'DataFrame' object has no attribute 'types'

# %% [markdown]
# ##Categorical values

# %%
sns.countplot(x = 'Sex', data=df)
plt.title('Sex Dist')
plt.show()

# %%
sns.countplot(x=df.Sex)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(df.Cabin)
# Out:
# <Axes: xlabel='count', ylabel='Cabin'>

# %%
sns.countplot(df.Embarked)
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
sns.countplot(x=df.Embarked)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# #biveriate annalysis

# %%
# how many male ans female were there who survived ?
sns.countplot(x='Sex',hue='Survived',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Survived',hue="Sex", data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.histplot(data=df,x='Age', hue = 'Survived', bins=30)
plt.title('Age distrubution wrt survival')
# Out:
# Text(0.5, 1.0, 'Age distrubution wrt survival')

# %%
sns.histplot(data=df,x='Fare', hue = 'Age', bins=30)
plt.title('Age distrubution wrt Fare')
# Out:
# Text(0.5, 1.0, 'Age distrubution wrt Fare')

# %%
df.Fare
# Out:
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64

# %% [markdown]
# FEATURE ENGINEERING

# %%
df['Family_Size'] = df['SibSp'] + df['Parch'] + 1
df.Family_Size
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: Family_Size, Length: 891, dtype: int64

# %%
#df['Alone']=np.where(df.Family_Size==1,1,0)
#df['Alone']=(df.Family_Size==1).astype(int)
#df.Alone
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    1
# 888    0
# 889    1
# 890    1
# Name: Alone, Length: 891, dtype: int64

# %%
df['Alone']=(df['Family_Size']==1).astype(int)
df.Alone
# Out:
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 886    1
# 887    1
# 888    0
# 889    1
# 890    1
# Name: Alone, Length: 891, dtype: int64

# %%
df['Family_Size']==1
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Family_Size, Length: 891, dtype: bool

# %%
df['Alone']=(df['Family_Size']==1)
df.Alone
# Out:
# 0      False
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887     True
# 888    False
# 889     True
# 890     True
# Name: Alone, Length: 891, dtype: bool

# %%
df.Cabin.isnull().sum()
# Out:
# np.int64(687)

# %%
df.Cabin
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df['Deck']=df['Cabin'].str[0]
df.Deck
# Out:
# 0      NaN
# 1        C
# 2      NaN
# 3        C
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      C
# 890    NaN
# Name: Deck, Length: 891, dtype: object

# %%
df.Deck=df.Deck.fillna("Unkown")

# %%
df.Deck
# Out:
# 0      Unkown
# 1           C
# 2      Unkown
# 3           C
# 4      Unkown
#         ...
# 886    Unkown
# 887         B
# 888    Unkown
# 889         C
# 890    Unkown
# Name: Deck, Length: 891, dtype: object

# %%
df.Deck.value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('Deck')
plt.ylabel('Freq')
plt.title('Deck Dist')
# Out:
# Text(0.5, 1.0, 'Deck Dist')

# %% [markdown]
# Categorize age into multiple category

# %%
df.Age.nunique()
# Out:
# 88

# %%
df['Age_cat']=pd.cut(df.Age,bins=[0,12,20,40,60,80,100],labels=['child','teen','young','adult','seniore','elder'])
df.Age_cat
# Out:
# 0      young
# 1      young
# 2      young
# 3      young
# 4      young
#        ...
# 886    young
# 887     teen
# 888      NaN
# 889    young
# 890    young
# Name: Age_cat, Length: 891, dtype: category
# Categories (6, object): ['child' < 'teen' < 'young' < 'adult' < 'seniore' < 'elder']

# %%
df.Age_cat.value_counts().plot(kind='bar',figsize=(10,5))
plt.xlabel('Deck')
plt.ylabel('Freq')
plt.title('Deck Dist')
# Out:
# Text(0.5, 1.0, 'Deck Dist')

# %% [markdown]
# outlier analysis

# %%
sns.boxplot(x='Age',data=df)
plt.xlabel("age")
plt.ylabel("freq")
plt.title("age outliers analysis dist")
# Out:
# Text(0.5, 1.0, 'age outliers analysis dist')

# %%
sns.boxplot(x='Age_cat',data=df)
plt.xlabel("age")
plt.ylabel("freq")
plt.title("age dist")
# Out:
# Text(0.5, 1.0, 'age dist')

# %%
sns.boxplot(x='Fare',data=df)
plt.xlabel("fare")
plt.ylabel("freq")
plt.title("fare dist")
# Out:
# Text(0.5, 1.0, 'fare dist')

# %%
sns.boxplot(x='Fare',y='Sex',data=df)
plt.xlabel("age")
plt.ylabel("freq")
plt.title("age dist")
# Out:
# Text(0.5, 1.0, 'age dist')

# %% [markdown]
# More distrubution graphs

# %%
sns.barplot(x='Age_cat',y='Survived',data=df)
# Out:
# <Axes: xlabel='Age_cat', ylabel='Survived'>

# %%
sns.barplot(x='Family_Size',y='Survived',data=df,palette='rainbow')
# Out:
# <Axes: xlabel='Family_Size', ylabel='Survived'>

# %%
#df['Not_Adult']=df['Age_cat'].apply(lambda x: 1 if x=='child' or x=='teen' else 0)
df['Child']=(df.Age<18).astype(int)
df.Child
sns.barplot(x='Child',y='Survived',data=df)
# Out:
# <Axes: xlabel='Child', ylabel='Survived'>

# %% [markdown]
# MULTIVARIENT ANALYSIS

# %%
#HEAT MAP (CO RELATION MATRIX )
corr_matrix=df[['Survived','Pclass','Age','Family_Size','Fare','Alone']].corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr_matrix,annot=True,fmt=".2f",cmap='coolwarm')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
#  12  Family_Size  891 non-null    int64
#  13  Alone        891 non-null    bool
#  14  Deck         891 non-null    object
#  15  Age_cat      714 non-null    category
#  16  Child        891 non-null    int64
# dtypes: bool(1), category(1), float64(2), int64(7), object(6)
# ...

# %%
Survived,Pclass,Age,Family_Size,Fare,Alone

# %% [markdown]
# PAIR PLOT

# %%
sns.pairplot(df,hue='Survived',vars=['Pclass','Age','Family_Size','Fare'],palette='rainbow')
